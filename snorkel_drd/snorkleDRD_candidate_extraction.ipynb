# %% [markdown]
# # Snorkel Candidate Extraction
#
# Note: do not launch jupyter notebook directly, use ```sh run.sh``` from snorkle repo
#
# https://github.com/UW-Deepdive-Infrastructure/stromatolites_snorkel/
#
# https://github.com/HazyResearch/snorkel

# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ['SNORKELDB']="postgres://postgres@localhost:5432/snorkel_postgres"

from snorkel import SnorkelSession
session = SnorkelSession()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from snorkel.models import Sentence, Document, candidate_subclass
from snorkel.candidates import Ngrams, CandidateExtractor
from snorkel.matchers import LocationMatcher, DictionaryMatch, RegexMatchSpan
from snorkel.viewer import SentenceNgramViewer

import os

sentences = session.query(Sentence).all()
len(sentences)
# Out:
# 147287

# %%
print("Documents:", session.query(Document).count())
print("Sentences:", session.query(Sentence).count())
# Out:
# ('Documents:', 254L)
# ('Sentences:', 147287L)

# %% [markdown]
# ## Candidate Extraction

# %%
ngram_rm = Ngrams(n_max=1)
ngram_names = Ngrams(n_max=9)

# %%
'''
Creating a Dam schema of relation mention to extract
Creates a database table if not available 
'''
DamCandidates = candidate_subclass('DamCandidates', ['removal_term', 'dam_name'])

# %%
dam_rm_matcher = RegexMatchSpan(rgx='dam|removal|remove|destroy|breach|removed|breached')

# %%
'''
Input: strings related to "removal", list of current removed dam names
Dam Names: https://github.com/bserna-usgs/DRD_DeepDive/blob/master/input/removedDams20151214.csv
'''
with open('./input/data/all_dams.csv', 'r') as f:
    dam_data = [i.split(',')[0] for i in f.readlines()]  # list of dam names

dam_name_matcher = DictionaryMatch(d=dam_data, ignore_case=False, longest_match_only=True)

# %%
'''
Extractor
'''
ce = CandidateExtractor(DamCandidates, [ngram_rm, ngram_names], [dam_rm_matcher, dam_name_matcher], 
                       symmetric_relations=True, nested_relations=False, self_relations=False)

# %%
'''
filter out sentences that have mentions of a LOCATION (NER)
Note - testing this might result in noun or proper noun 
'''
def number_of_dams(sentence):
    active_sequence = False
    count = 0 
    for tag in sentence.ner_tags:
        if tag == 'LOCATION' and not active_sequence:
            active_sequence = True
            count += 1
        elif tag != 'LOCATION' and active_sequence:
            active_sequence = False
    return count

# %%
'''
train-test split (from tutorial)
'''
docs = session.query(Document).order_by(Document.name).all()
ld = len(docs)

train_sents = set()
dev_sents = set()
test_sents = set()
splits = (0.8, 0.9) if 'CI' in os.environ else (0.9, 0.95)

for i, doc in enumerate(docs):
    for s in doc.sentences:
        if number_of_dams(s) < 2:
            if i < splits[0] * ld:
                train_sents.add(s)
            elif i < splits[1] * ld:
                dev_sents.add(s)
            else:
                test_sents.add(s)
                
len(train_sents), len(dev_sents), len(test_sents)

# %% [markdown]
# ## Running Candidate Extractor

# %%
#docs = session.query(Document).order_by(Document.name).all()
#ce.apply(docs, split=0)
# %time ce.apply(train_sents, split=0)
# Out:
# Clearing existing...
# Running UDF...
# [========================================] 100%%
#
# CPU times: user 2min 25s, sys: 2.38 s, total: 2min 28s
# Wall time: 2min 31s

# %%
'''
get candidates
'''
train_candidates = session.query(DamCandidates).filter(DamCandidates.split == 0).all()
print('Number of candidates: ' + len(train_candidates))
# Out:
# ('Number of candidates: ', 265)

# %% [markdown]
# ## Viewer to inspect candidates
#
# ```sh
# jupyter nbextension enable --py widgetsnbextension --sys-prefix
# ```

# %%
if 'CI' not in os.environ:
    sv = SentenceNgramViewer(train_candidates[:], session)
else:
    sv = None

# %%
sv
# Out:
# The installed widget Javascript is the wrong version.
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /Users/bserna/Developer/geodeepdive_template/snorkel/snorkel/viewer.pyc in handle_label_event(self, _, content, buffers)
#     214
#     215                 # Create AnnotatorLabel
# --> 216                 self.annotations[cid] = GoldLabel(key=self.annotator, candidate=candidate, value=value)
#     217                 self.session.add(self.annotations[cid])
#     218
#
# <string> in __init__(self, **kwargs)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     412         except:
#     413             with util.safe_reraise():
# --> 414                 manager.dispatch.init_failure(self, args, kwargs)
#     415
#     416     def get_history(self, key, passive):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/util/langhelpers.pyc in __exit__(self, type_, value, traceback)
#      58             exc_type, exc_value, exc_tb = self._exc_info
#      59             self._exc_info = None   # remove potential circular references
# ---> 60             compat.reraise(exc_type, exc_value, exc_tb)
#      61         else:
#      62             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     409
#     410         try:
# --> 411             return manager.original_init(*mixed[1:], **kwargs)
#     412         except:
#     413             with util.safe_reraise():
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/ext/declarative/base.pyc in _declarative_constructor(self, **kwargs)
#     648                 "%r is an invalid keyword argument for %s" %
#     649                 (k, cls_.__name__))
# --> 650         setattr(self, k, kwargs[k])
#     651 _declarative_constructor.__name__ = '__init__'
#     652
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in __set__(self, instance, value)
#     222     def __set__(self, instance, value):
#     223         self.impl.set(instance_state(instance),
# --> 224                       instance_dict(instance), value, None)
#     225
#     226     def __delete__(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in set(self, state, dict_, value, initiator, passive, check_old, pop)
#     810                     ))
#     811
# --> 812         value = self.fire_replace_event(state, dict_, value, old, initiator)
#     813         dict_[self.key] = value
#     814
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_replace_event(self, state, dict_, value, previous, initiator)
#     832             value = fn(
#     833                 state, value, previous, initiator or
# --> 834                 self._replace_token or self._init_append_or_replace_token())
#     835
#     836         state._modified_event(dict_, self, previous)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in emit_backref_from_scalar_set_event(state, child, oldchild, initiator)
#    1186                     state.obj(),
#    1187                     initiator,
# -> 1188                     passive=PASSIVE_NO_FETCH)
#    1189         return child
#    1190
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in append(self, state, dict_, value, initiator, passive)
#    1001         collection = self.get_collection(state, dict_, passive=passive)
#    1002         if collection is PASSIVE_NO_RESULT:
# -> 1003             value = self.fire_append_event(state, dict_, value, initiator)
#    1004             assert self.key not in dict_, \
#    1005                 "Collection was loaded during event handling."
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_append_event(self, state, dict_, value, initiator)
#     949             value = fn(
#     950                 state, value,
# --> 951                 initiator or self._append_token or self._init_append_token())
#     952
#     953         state._modified_event(dict_, self, NEVER_SET, True)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/unitofwork.pyc in append(state, item, initiator)
#      45                 (prop.cascade_backrefs or key == initiator.key) and \
#      46                     not sess._contains_state(item_state):
# ---> 47                 sess._save_or_update_state(item_state)
#      48         return item
#      49
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_state(self, state)
#    1694                 state,
#    1695                 halt_on=self._contains_state):
# -> 1696             self._save_or_update_impl(st_)
#    1697
#    1698     def delete(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_impl(self, state)
#    1993             self._save_impl(state)
#    1994         else:
# -> 1995             self._update_impl(state)
#    1996
#    1997     def enable_relationship_loading(self, obj):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _update_impl(self, state, revert_deletion)
#    1976             return
#    1977
# -> 1978         to_attach = self._before_attach(state, obj)
#    1979
#    1980         self._deleted.pop(state, None)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _before_attach(self, state, obj)
#    2060                 "Object '%s' is already attached to session '%s' "
#    2061                 "(this is '%s')" % (state_str(state),
# -> 2062                                     state.session_id, self.hash_key))
#    2063
#    2064         self.dispatch.before_attach(self, obj)
#
# InvalidRequestError: Object '<DamCandidates at 0x130b1ab50>' is already attached to session '1' (this is '4')
# ---------------------------------------------------------------------------
# UnmappedInstanceError                     Traceback (most recent call last)
# /Users/bserna/Developer/geodeepdive_template/snorkel/snorkel/viewer.pyc in handle_label_event(self, _, content, buffers)
#     228         elif content.get('event', '') == 'delete_label':
#     229             cid = content.get('cid', None)
# --> 230             self.session.delete(self.annotations[cid])
#     231             self.annotations[cid] = None
#     232             self.session.delete(self.annotations_stable[cid])
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in delete(self, instance)
#    1708             state = attributes.instance_state(instance)
#    1709         except exc.NO_STATE:
# -> 1710             raise exc.UnmappedInstanceError(instance)
#    1711
#    1712         self._delete_impl(state, instance, head=True)
#
# UnmappedInstanceError: Class '__builtin__.NoneType' is not mapped
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /Users/bserna/Developer/geodeepdive_template/snorkel/snorkel/viewer.pyc in handle_label_event(self, _, content, buffers)
#     214
#     215                 # Create AnnotatorLabel
# --> 216                 self.annotations[cid] = GoldLabel(key=self.annotator, candidate=candidate, value=value)
#     217                 self.session.add(self.annotations[cid])
#     218
#
# <string> in __init__(self, **kwargs)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     412         except:
#     413             with util.safe_reraise():
# --> 414                 manager.dispatch.init_failure(self, args, kwargs)
#     415
#     416     def get_history(self, key, passive):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/util/langhelpers.pyc in __exit__(self, type_, value, traceback)
#      58             exc_type, exc_value, exc_tb = self._exc_info
#      59             self._exc_info = None   # remove potential circular references
# ---> 60             compat.reraise(exc_type, exc_value, exc_tb)
#      61         else:
#      62             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     409
#     410         try:
# --> 411             return manager.original_init(*mixed[1:], **kwargs)
#     412         except:
#     413             with util.safe_reraise():
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/ext/declarative/base.pyc in _declarative_constructor(self, **kwargs)
#     648                 "%r is an invalid keyword argument for %s" %
#     649                 (k, cls_.__name__))
# --> 650         setattr(self, k, kwargs[k])
#     651 _declarative_constructor.__name__ = '__init__'
#     652
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in __set__(self, instance, value)
#     222     def __set__(self, instance, value):
#     223         self.impl.set(instance_state(instance),
# --> 224                       instance_dict(instance), value, None)
#     225
#     226     def __delete__(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in set(self, state, dict_, value, initiator, passive, check_old, pop)
#     810                     ))
#     811
# --> 812         value = self.fire_replace_event(state, dict_, value, old, initiator)
#     813         dict_[self.key] = value
#     814
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_replace_event(self, state, dict_, value, previous, initiator)
#     832             value = fn(
#     833                 state, value, previous, initiator or
# --> 834                 self._replace_token or self._init_append_or_replace_token())
#     835
#     836         state._modified_event(dict_, self, previous)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in emit_backref_from_scalar_set_event(state, child, oldchild, initiator)
#    1186                     state.obj(),
#    1187                     initiator,
# -> 1188                     passive=PASSIVE_NO_FETCH)
#    1189         return child
#    1190
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in append(self, state, dict_, value, initiator, passive)
#    1001         collection = self.get_collection(state, dict_, passive=passive)
#    1002         if collection is PASSIVE_NO_RESULT:
# -> 1003             value = self.fire_append_event(state, dict_, value, initiator)
#    1004             assert self.key not in dict_, \
#    1005                 "Collection was loaded during event handling."
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_append_event(self, state, dict_, value, initiator)
#     949             value = fn(
#     950                 state, value,
# --> 951                 initiator or self._append_token or self._init_append_token())
#     952
#     953         state._modified_event(dict_, self, NEVER_SET, True)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/unitofwork.pyc in append(state, item, initiator)
#      45                 (prop.cascade_backrefs or key == initiator.key) and \
#      46                     not sess._contains_state(item_state):
# ---> 47                 sess._save_or_update_state(item_state)
#      48         return item
#      49
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_state(self, state)
#    1694                 state,
#    1695                 halt_on=self._contains_state):
# -> 1696             self._save_or_update_impl(st_)
#    1697
#    1698     def delete(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_impl(self, state)
#    1993             self._save_impl(state)
#    1994         else:
# -> 1995             self._update_impl(state)
#    1996
#    1997     def enable_relationship_loading(self, obj):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _update_impl(self, state, revert_deletion)
#    1976             return
#    1977
# -> 1978         to_attach = self._before_attach(state, obj)
#    1979
#    1980         self._deleted.pop(state, None)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _before_attach(self, state, obj)
#    2060                 "Object '%s' is already attached to session '%s' "
#    2061                 "(this is '%s')" % (state_str(state),
# -> 2062                                     state.session_id, self.hash_key))
#    2063
#    2064         self.dispatch.before_attach(self, obj)
#
# InvalidRequestError: Object '<DamCandidates at 0x130b1ab50>' is already attached to session '1' (this is '4')
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /Users/bserna/Developer/geodeepdive_template/snorkel/snorkel/viewer.pyc in handle_label_event(self, _, content, buffers)
#     214
#     215                 # Create AnnotatorLabel
# --> 216                 self.annotations[cid] = GoldLabel(key=self.annotator, candidate=candidate, value=value)
#     217                 self.session.add(self.annotations[cid])
#     218
#
# <string> in __init__(self, **kwargs)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     412         except:
#     413             with util.safe_reraise():
# --> 414                 manager.dispatch.init_failure(self, args, kwargs)
#     415
#     416     def get_history(self, key, passive):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/util/langhelpers.pyc in __exit__(self, type_, value, traceback)
#      58             exc_type, exc_value, exc_tb = self._exc_info
#      59             self._exc_info = None   # remove potential circular references
# ---> 60             compat.reraise(exc_type, exc_value, exc_tb)
#      61         else:
#      62             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     409
#     410         try:
# --> 411             return manager.original_init(*mixed[1:], **kwargs)
#     412         except:
#     413             with util.safe_reraise():
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/ext/declarative/base.pyc in _declarative_constructor(self, **kwargs)
#     648                 "%r is an invalid keyword argument for %s" %
#     649                 (k, cls_.__name__))
# --> 650         setattr(self, k, kwargs[k])
#     651 _declarative_constructor.__name__ = '__init__'
#     652
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in __set__(self, instance, value)
#     222     def __set__(self, instance, value):
#     223         self.impl.set(instance_state(instance),
# --> 224                       instance_dict(instance), value, None)
#     225
#     226     def __delete__(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in set(self, state, dict_, value, initiator, passive, check_old, pop)
#     810                     ))
#     811
# --> 812         value = self.fire_replace_event(state, dict_, value, old, initiator)
#     813         dict_[self.key] = value
#     814
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_replace_event(self, state, dict_, value, previous, initiator)
#     832             value = fn(
#     833                 state, value, previous, initiator or
# --> 834                 self._replace_token or self._init_append_or_replace_token())
#     835
#     836         state._modified_event(dict_, self, previous)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in emit_backref_from_scalar_set_event(state, child, oldchild, initiator)
#    1186                     state.obj(),
#    1187                     initiator,
# -> 1188                     passive=PASSIVE_NO_FETCH)
#    1189         return child
#    1190
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in append(self, state, dict_, value, initiator, passive)
#    1001         collection = self.get_collection(state, dict_, passive=passive)
#    1002         if collection is PASSIVE_NO_RESULT:
# -> 1003             value = self.fire_append_event(state, dict_, value, initiator)
#    1004             assert self.key not in dict_, \
#    1005                 "Collection was loaded during event handling."
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_append_event(self, state, dict_, value, initiator)
#     949             value = fn(
#     950                 state, value,
# --> 951                 initiator or self._append_token or self._init_append_token())
#     952
#     953         state._modified_event(dict_, self, NEVER_SET, True)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/unitofwork.pyc in append(state, item, initiator)
#      45                 (prop.cascade_backrefs or key == initiator.key) and \
#      46                     not sess._contains_state(item_state):
# ---> 47                 sess._save_or_update_state(item_state)
#      48         return item
#      49
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_state(self, state)
#    1694                 state,
#    1695                 halt_on=self._contains_state):
# -> 1696             self._save_or_update_impl(st_)
#    1697
#    1698     def delete(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_impl(self, state)
#    1993             self._save_impl(state)
#    1994         else:
# -> 1995             self._update_impl(state)
#    1996
#    1997     def enable_relationship_loading(self, obj):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _update_impl(self, state, revert_deletion)
#    1976             return
#    1977
# -> 1978         to_attach = self._before_attach(state, obj)
#    1979
#    1980         self._deleted.pop(state, None)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _before_attach(self, state, obj)
#    2060                 "Object '%s' is already attached to session '%s' "
#    2061                 "(this is '%s')" % (state_str(state),
# -> 2062                                     state.session_id, self.hash_key))
#    2063
#    2064         self.dispatch.before_attach(self, obj)
#
# InvalidRequestError: Object '<DamCandidates at 0x13f042410>' is already attached to session '1' (this is '4')
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /Users/bserna/Developer/geodeepdive_template/snorkel/snorkel/viewer.pyc in handle_label_event(self, _, content, buffers)
#     214
#     215                 # Create AnnotatorLabel
# --> 216                 self.annotations[cid] = GoldLabel(key=self.annotator, candidate=candidate, value=value)
#     217                 self.session.add(self.annotations[cid])
#     218
#
# <string> in __init__(self, **kwargs)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     412         except:
#     413             with util.safe_reraise():
# --> 414                 manager.dispatch.init_failure(self, args, kwargs)
#     415
#     416     def get_history(self, key, passive):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/util/langhelpers.pyc in __exit__(self, type_, value, traceback)
#      58             exc_type, exc_value, exc_tb = self._exc_info
#      59             self._exc_info = None   # remove potential circular references
# ---> 60             compat.reraise(exc_type, exc_value, exc_tb)
#      61         else:
#      62             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     409
#     410         try:
# --> 411             return manager.original_init(*mixed[1:], **kwargs)
#     412         except:
#     413             with util.safe_reraise():
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/ext/declarative/base.pyc in _declarative_constructor(self, **kwargs)
#     648                 "%r is an invalid keyword argument for %s" %
#     649                 (k, cls_.__name__))
# --> 650         setattr(self, k, kwargs[k])
#     651 _declarative_constructor.__name__ = '__init__'
#     652
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in __set__(self, instance, value)
#     222     def __set__(self, instance, value):
#     223         self.impl.set(instance_state(instance),
# --> 224                       instance_dict(instance), value, None)
#     225
#     226     def __delete__(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in set(self, state, dict_, value, initiator, passive, check_old, pop)
#     810                     ))
#     811
# --> 812         value = self.fire_replace_event(state, dict_, value, old, initiator)
#     813         dict_[self.key] = value
#     814
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_replace_event(self, state, dict_, value, previous, initiator)
#     832             value = fn(
#     833                 state, value, previous, initiator or
# --> 834                 self._replace_token or self._init_append_or_replace_token())
#     835
#     836         state._modified_event(dict_, self, previous)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in emit_backref_from_scalar_set_event(state, child, oldchild, initiator)
#    1186                     state.obj(),
#    1187                     initiator,
# -> 1188                     passive=PASSIVE_NO_FETCH)
#    1189         return child
#    1190
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in append(self, state, dict_, value, initiator, passive)
#    1001         collection = self.get_collection(state, dict_, passive=passive)
#    1002         if collection is PASSIVE_NO_RESULT:
# -> 1003             value = self.fire_append_event(state, dict_, value, initiator)
#    1004             assert self.key not in dict_, \
#    1005                 "Collection was loaded during event handling."
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_append_event(self, state, dict_, value, initiator)
#     949             value = fn(
#     950                 state, value,
# --> 951                 initiator or self._append_token or self._init_append_token())
#     952
#     953         state._modified_event(dict_, self, NEVER_SET, True)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/unitofwork.pyc in append(state, item, initiator)
#      45                 (prop.cascade_backrefs or key == initiator.key) and \
#      46                     not sess._contains_state(item_state):
# ---> 47                 sess._save_or_update_state(item_state)
#      48         return item
#      49
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_state(self, state)
#    1694                 state,
#    1695                 halt_on=self._contains_state):
# -> 1696             self._save_or_update_impl(st_)
#    1697
#    1698     def delete(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_impl(self, state)
#    1993             self._save_impl(state)
#    1994         else:
# -> 1995             self._update_impl(state)
#    1996
#    1997     def enable_relationship_loading(self, obj):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _update_impl(self, state, revert_deletion)
#    1976             return
#    1977
# -> 1978         to_attach = self._before_attach(state, obj)
#    1979
#    1980         self._deleted.pop(state, None)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _before_attach(self, state, obj)
#    2060                 "Object '%s' is already attached to session '%s' "
#    2061                 "(this is '%s')" % (state_str(state),
# -> 2062                                     state.session_id, self.hash_key))
#    2063
#    2064         self.dispatch.before_attach(self, obj)
#
# InvalidRequestError: Object '<DamCandidates at 0x11dda1dd0>' is already attached to session '1' (this is '4')
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /Users/bserna/Developer/geodeepdive_template/snorkel/snorkel/viewer.pyc in handle_label_event(self, _, content, buffers)
#     214
#     215                 # Create AnnotatorLabel
# --> 216                 self.annotations[cid] = GoldLabel(key=self.annotator, candidate=candidate, value=value)
#     217                 self.session.add(self.annotations[cid])
#     218
#
# <string> in __init__(self, **kwargs)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     412         except:
#     413             with util.safe_reraise():
# --> 414                 manager.dispatch.init_failure(self, args, kwargs)
#     415
#     416     def get_history(self, key, passive):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/util/langhelpers.pyc in __exit__(self, type_, value, traceback)
#      58             exc_type, exc_value, exc_tb = self._exc_info
#      59             self._exc_info = None   # remove potential circular references
# ---> 60             compat.reraise(exc_type, exc_value, exc_tb)
#      61         else:
#      62             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     409
#     410         try:
# --> 411             return manager.original_init(*mixed[1:], **kwargs)
#     412         except:
#     413             with util.safe_reraise():
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/ext/declarative/base.pyc in _declarative_constructor(self, **kwargs)
#     648                 "%r is an invalid keyword argument for %s" %
#     649                 (k, cls_.__name__))
# --> 650         setattr(self, k, kwargs[k])
#     651 _declarative_constructor.__name__ = '__init__'
#     652
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in __set__(self, instance, value)
#     222     def __set__(self, instance, value):
#     223         self.impl.set(instance_state(instance),
# --> 224                       instance_dict(instance), value, None)
#     225
#     226     def __delete__(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in set(self, state, dict_, value, initiator, passive, check_old, pop)
#     810                     ))
#     811
# --> 812         value = self.fire_replace_event(state, dict_, value, old, initiator)
#     813         dict_[self.key] = value
#     814
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_replace_event(self, state, dict_, value, previous, initiator)
#     832             value = fn(
#     833                 state, value, previous, initiator or
# --> 834                 self._replace_token or self._init_append_or_replace_token())
#     835
#     836         state._modified_event(dict_, self, previous)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in emit_backref_from_scalar_set_event(state, child, oldchild, initiator)
#    1186                     state.obj(),
#    1187                     initiator,
# -> 1188                     passive=PASSIVE_NO_FETCH)
#    1189         return child
#    1190
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in append(self, state, dict_, value, initiator, passive)
#    1001         collection = self.get_collection(state, dict_, passive=passive)
#    1002         if collection is PASSIVE_NO_RESULT:
# -> 1003             value = self.fire_append_event(state, dict_, value, initiator)
#    1004             assert self.key not in dict_, \
#    1005                 "Collection was loaded during event handling."
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_append_event(self, state, dict_, value, initiator)
#     949             value = fn(
#     950                 state, value,
# --> 951                 initiator or self._append_token or self._init_append_token())
#     952
#     953         state._modified_event(dict_, self, NEVER_SET, True)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/unitofwork.pyc in append(state, item, initiator)
#      45                 (prop.cascade_backrefs or key == initiator.key) and \
#      46                     not sess._contains_state(item_state):
# ---> 47                 sess._save_or_update_state(item_state)
#      48         return item
#      49
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_state(self, state)
#    1694                 state,
#    1695                 halt_on=self._contains_state):
# -> 1696             self._save_or_update_impl(st_)
#    1697
#    1698     def delete(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_impl(self, state)
#    1993             self._save_impl(state)
#    1994         else:
# -> 1995             self._update_impl(state)
#    1996
#    1997     def enable_relationship_loading(self, obj):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _update_impl(self, state, revert_deletion)
#    1976             return
#    1977
# -> 1978         to_attach = self._before_attach(state, obj)
#    1979
#    1980         self._deleted.pop(state, None)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _before_attach(self, state, obj)
#    2060                 "Object '%s' is already attached to session '%s' "
#    2061                 "(this is '%s')" % (state_str(state),
# -> 2062                                     state.session_id, self.hash_key))
#    2063
#    2064         self.dispatch.before_attach(self, obj)
#
# InvalidRequestError: Object '<DamCandidates at 0x13ba4ce10>' is already attached to session '1' (this is '4')
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /Users/bserna/Developer/geodeepdive_template/snorkel/snorkel/viewer.pyc in handle_label_event(self, _, content, buffers)
#     214
#     215                 # Create AnnotatorLabel
# --> 216                 self.annotations[cid] = GoldLabel(key=self.annotator, candidate=candidate, value=value)
#     217                 self.session.add(self.annotations[cid])
#     218
#
# <string> in __init__(self, **kwargs)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     412         except:
#     413             with util.safe_reraise():
# --> 414                 manager.dispatch.init_failure(self, args, kwargs)
#     415
#     416     def get_history(self, key, passive):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/util/langhelpers.pyc in __exit__(self, type_, value, traceback)
#      58             exc_type, exc_value, exc_tb = self._exc_info
#      59             self._exc_info = None   # remove potential circular references
# ---> 60             compat.reraise(exc_type, exc_value, exc_tb)
#      61         else:
#      62             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     409
#     410         try:
# --> 411             return manager.original_init(*mixed[1:], **kwargs)
#     412         except:
#     413             with util.safe_reraise():
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/ext/declarative/base.pyc in _declarative_constructor(self, **kwargs)
#     648                 "%r is an invalid keyword argument for %s" %
#     649                 (k, cls_.__name__))
# --> 650         setattr(self, k, kwargs[k])
#     651 _declarative_constructor.__name__ = '__init__'
#     652
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in __set__(self, instance, value)
#     222     def __set__(self, instance, value):
#     223         self.impl.set(instance_state(instance),
# --> 224                       instance_dict(instance), value, None)
#     225
#     226     def __delete__(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in set(self, state, dict_, value, initiator, passive, check_old, pop)
#     810                     ))
#     811
# --> 812         value = self.fire_replace_event(state, dict_, value, old, initiator)
#     813         dict_[self.key] = value
#     814
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_replace_event(self, state, dict_, value, previous, initiator)
#     832             value = fn(
#     833                 state, value, previous, initiator or
# --> 834                 self._replace_token or self._init_append_or_replace_token())
#     835
#     836         state._modified_event(dict_, self, previous)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in emit_backref_from_scalar_set_event(state, child, oldchild, initiator)
#    1186                     state.obj(),
#    1187                     initiator,
# -> 1188                     passive=PASSIVE_NO_FETCH)
#    1189         return child
#    1190
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in append(self, state, dict_, value, initiator, passive)
#    1001         collection = self.get_collection(state, dict_, passive=passive)
#    1002         if collection is PASSIVE_NO_RESULT:
# -> 1003             value = self.fire_append_event(state, dict_, value, initiator)
#    1004             assert self.key not in dict_, \
#    1005                 "Collection was loaded during event handling."
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_append_event(self, state, dict_, value, initiator)
#     949             value = fn(
#     950                 state, value,
# --> 951                 initiator or self._append_token or self._init_append_token())
#     952
#     953         state._modified_event(dict_, self, NEVER_SET, True)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/unitofwork.pyc in append(state, item, initiator)
#      45                 (prop.cascade_backrefs or key == initiator.key) and \
#      46                     not sess._contains_state(item_state):
# ---> 47                 sess._save_or_update_state(item_state)
#      48         return item
#      49
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_state(self, state)
#    1694                 state,
#    1695                 halt_on=self._contains_state):
# -> 1696             self._save_or_update_impl(st_)
#    1697
#    1698     def delete(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_impl(self, state)
#    1993             self._save_impl(state)
#    1994         else:
# -> 1995             self._update_impl(state)
#    1996
#    1997     def enable_relationship_loading(self, obj):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _update_impl(self, state, revert_deletion)
#    1976             return
#    1977
# -> 1978         to_attach = self._before_attach(state, obj)
#    1979
#    1980         self._deleted.pop(state, None)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _before_attach(self, state, obj)
#    2060                 "Object '%s' is already attached to session '%s' "
#    2061                 "(this is '%s')" % (state_str(state),
# -> 2062                                     state.session_id, self.hash_key))
#    2063
#    2064         self.dispatch.before_attach(self, obj)
#
# InvalidRequestError: Object '<DamCandidates at 0x12dd7efd0>' is already attached to session '1' (this is '4')
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /Users/bserna/Developer/geodeepdive_template/snorkel/snorkel/viewer.pyc in handle_label_event(self, _, content, buffers)
#     214
#     215                 # Create AnnotatorLabel
# --> 216                 self.annotations[cid] = GoldLabel(key=self.annotator, candidate=candidate, value=value)
#     217                 self.session.add(self.annotations[cid])
#     218
#
# <string> in __init__(self, **kwargs)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     412         except:
#     413             with util.safe_reraise():
# --> 414                 manager.dispatch.init_failure(self, args, kwargs)
#     415
#     416     def get_history(self, key, passive):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/util/langhelpers.pyc in __exit__(self, type_, value, traceback)
#      58             exc_type, exc_value, exc_tb = self._exc_info
#      59             self._exc_info = None   # remove potential circular references
# ---> 60             compat.reraise(exc_type, exc_value, exc_tb)
#      61         else:
#      62             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     409
#     410         try:
# --> 411             return manager.original_init(*mixed[1:], **kwargs)
#     412         except:
#     413             with util.safe_reraise():
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/ext/declarative/base.pyc in _declarative_constructor(self, **kwargs)
#     648                 "%r is an invalid keyword argument for %s" %
#     649                 (k, cls_.__name__))
# --> 650         setattr(self, k, kwargs[k])
#     651 _declarative_constructor.__name__ = '__init__'
#     652
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in __set__(self, instance, value)
#     222     def __set__(self, instance, value):
#     223         self.impl.set(instance_state(instance),
# --> 224                       instance_dict(instance), value, None)
#     225
#     226     def __delete__(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in set(self, state, dict_, value, initiator, passive, check_old, pop)
#     810                     ))
#     811
# --> 812         value = self.fire_replace_event(state, dict_, value, old, initiator)
#     813         dict_[self.key] = value
#     814
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_replace_event(self, state, dict_, value, previous, initiator)
#     832             value = fn(
#     833                 state, value, previous, initiator or
# --> 834                 self._replace_token or self._init_append_or_replace_token())
#     835
#     836         state._modified_event(dict_, self, previous)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in emit_backref_from_scalar_set_event(state, child, oldchild, initiator)
#    1186                     state.obj(),
#    1187                     initiator,
# -> 1188                     passive=PASSIVE_NO_FETCH)
#    1189         return child
#    1190
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in append(self, state, dict_, value, initiator, passive)
#    1001         collection = self.get_collection(state, dict_, passive=passive)
#    1002         if collection is PASSIVE_NO_RESULT:
# -> 1003             value = self.fire_append_event(state, dict_, value, initiator)
#    1004             assert self.key not in dict_, \
#    1005                 "Collection was loaded during event handling."
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_append_event(self, state, dict_, value, initiator)
#     949             value = fn(
#     950                 state, value,
# --> 951                 initiator or self._append_token or self._init_append_token())
#     952
#     953         state._modified_event(dict_, self, NEVER_SET, True)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/unitofwork.pyc in append(state, item, initiator)
#      45                 (prop.cascade_backrefs or key == initiator.key) and \
#      46                     not sess._contains_state(item_state):
# ---> 47                 sess._save_or_update_state(item_state)
#      48         return item
#      49
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_state(self, state)
#    1694                 state,
#    1695                 halt_on=self._contains_state):
# -> 1696             self._save_or_update_impl(st_)
#    1697
#    1698     def delete(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_impl(self, state)
#    1993             self._save_impl(state)
#    1994         else:
# -> 1995             self._update_impl(state)
#    1996
#    1997     def enable_relationship_loading(self, obj):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _update_impl(self, state, revert_deletion)
#    1976             return
#    1977
# -> 1978         to_attach = self._before_attach(state, obj)
#    1979
#    1980         self._deleted.pop(state, None)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _before_attach(self, state, obj)
#    2060                 "Object '%s' is already attached to session '%s' "
#    2061                 "(this is '%s')" % (state_str(state),
# -> 2062                                     state.session_id, self.hash_key))
#    2063
#    2064         self.dispatch.before_attach(self, obj)
#
# InvalidRequestError: Object '<DamCandidates at 0x12dd7ec50>' is already attached to session '1' (this is '4')
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /Users/bserna/Developer/geodeepdive_template/snorkel/snorkel/viewer.pyc in handle_label_event(self, _, content, buffers)
#     214
#     215                 # Create AnnotatorLabel
# --> 216                 self.annotations[cid] = GoldLabel(key=self.annotator, candidate=candidate, value=value)
#     217                 self.session.add(self.annotations[cid])
#     218
#
# <string> in __init__(self, **kwargs)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     412         except:
#     413             with util.safe_reraise():
# --> 414                 manager.dispatch.init_failure(self, args, kwargs)
#     415
#     416     def get_history(self, key, passive):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/util/langhelpers.pyc in __exit__(self, type_, value, traceback)
#      58             exc_type, exc_value, exc_tb = self._exc_info
#      59             self._exc_info = None   # remove potential circular references
# ---> 60             compat.reraise(exc_type, exc_value, exc_tb)
#      61         else:
#      62             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     409
#     410         try:
# --> 411             return manager.original_init(*mixed[1:], **kwargs)
#     412         except:
#     413             with util.safe_reraise():
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/ext/declarative/base.pyc in _declarative_constructor(self, **kwargs)
#     648                 "%r is an invalid keyword argument for %s" %
#     649                 (k, cls_.__name__))
# --> 650         setattr(self, k, kwargs[k])
#     651 _declarative_constructor.__name__ = '__init__'
#     652
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in __set__(self, instance, value)
#     222     def __set__(self, instance, value):
#     223         self.impl.set(instance_state(instance),
# --> 224                       instance_dict(instance), value, None)
#     225
#     226     def __delete__(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in set(self, state, dict_, value, initiator, passive, check_old, pop)
#     810                     ))
#     811
# --> 812         value = self.fire_replace_event(state, dict_, value, old, initiator)
#     813         dict_[self.key] = value
#     814
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_replace_event(self, state, dict_, value, previous, initiator)
#     832             value = fn(
#     833                 state, value, previous, initiator or
# --> 834                 self._replace_token or self._init_append_or_replace_token())
#     835
#     836         state._modified_event(dict_, self, previous)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in emit_backref_from_scalar_set_event(state, child, oldchild, initiator)
#    1186                     state.obj(),
#    1187                     initiator,
# -> 1188                     passive=PASSIVE_NO_FETCH)
#    1189         return child
#    1190
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in append(self, state, dict_, value, initiator, passive)
#    1001         collection = self.get_collection(state, dict_, passive=passive)
#    1002         if collection is PASSIVE_NO_RESULT:
# -> 1003             value = self.fire_append_event(state, dict_, value, initiator)
#    1004             assert self.key not in dict_, \
#    1005                 "Collection was loaded during event handling."
#
# ...
#     810                     ))
#     811
# --> 812         value = self.fire_replace_event(state, dict_, value, old, initiator)
#     813         dict_[self.key] = value
#     814
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_replace_event(self, state, dict_, value, previous, initiator)
#     832             value = fn(
#     833                 state, value, previous, initiator or
# --> 834                 self._replace_token or self._init_append_or_replace_token())
#     835
#     836         state._modified_event(dict_, self, previous)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in emit_backref_from_scalar_set_event(state, child, oldchild, initiator)
#    1186                     state.obj(),
#    1187                     initiator,
# -> 1188                     passive=PASSIVE_NO_FETCH)
#    1189         return child
#    1190
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in append(self, state, dict_, value, initiator, passive)
#    1001         collection = self.get_collection(state, dict_, passive=passive)
#    1002         if collection is PASSIVE_NO_RESULT:
# -> 1003             value = self.fire_append_event(state, dict_, value, initiator)
#    1004             assert self.key not in dict_, \
#    1005                 "Collection was loaded during event handling."
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_append_event(self, state, dict_, value, initiator)
#     949             value = fn(
#     950                 state, value,
# --> 951                 initiator or self._append_token or self._init_append_token())
#     952
#     953         state._modified_event(dict_, self, NEVER_SET, True)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/unitofwork.pyc in append(state, item, initiator)
#      45                 (prop.cascade_backrefs or key == initiator.key) and \
#      46                     not sess._contains_state(item_state):
# ---> 47                 sess._save_or_update_state(item_state)
#      48         return item
#      49
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_state(self, state)
#    1694                 state,
#    1695                 halt_on=self._contains_state):
# -> 1696             self._save_or_update_impl(st_)
#    1697
#    1698     def delete(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_impl(self, state)
#    1993             self._save_impl(state)
#    1994         else:
# -> 1995             self._update_impl(state)
#    1996
#    1997     def enable_relationship_loading(self, obj):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _update_impl(self, state, revert_deletion)
#    1976             return
#    1977
# -> 1978         to_attach = self._before_attach(state, obj)
#    1979
#    1980         self._deleted.pop(state, None)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _before_attach(self, state, obj)
#    2060                 "Object '%s' is already attached to session '%s' "
#    2061                 "(this is '%s')" % (state_str(state),
# -> 2062                                     state.session_id, self.hash_key))
#    2063
#    2064         self.dispatch.before_attach(self, obj)
#
# InvalidRequestError: Object '<DamCandidates at 0x1399aced0>' is already attached to session '1' (this is '4')
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /Users/bserna/Developer/geodeepdive_template/snorkel/snorkel/viewer.pyc in handle_label_event(self, _, content, buffers)
#     214
#     215                 # Create AnnotatorLabel
# --> 216                 self.annotations[cid] = GoldLabel(key=self.annotator, candidate=candidate, value=value)
#     217                 self.session.add(self.annotations[cid])
#     218
#
# <string> in __init__(self, **kwargs)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     412         except:
#     413             with util.safe_reraise():
# --> 414                 manager.dispatch.init_failure(self, args, kwargs)
#     415
#     416     def get_history(self, key, passive):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/util/langhelpers.pyc in __exit__(self, type_, value, traceback)
#      58             exc_type, exc_value, exc_tb = self._exc_info
#      59             self._exc_info = None   # remove potential circular references
# ---> 60             compat.reraise(exc_type, exc_value, exc_tb)
#      61         else:
#      62             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     409
#     410         try:
# --> 411             return manager.original_init(*mixed[1:], **kwargs)
#     412         except:
#     413             with util.safe_reraise():
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/ext/declarative/base.pyc in _declarative_constructor(self, **kwargs)
#     648                 "%r is an invalid keyword argument for %s" %
#     649                 (k, cls_.__name__))
# --> 650         setattr(self, k, kwargs[k])
#     651 _declarative_constructor.__name__ = '__init__'
#     652
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in __set__(self, instance, value)
#     222     def __set__(self, instance, value):
#     223         self.impl.set(instance_state(instance),
# --> 224                       instance_dict(instance), value, None)
#     225
#     226     def __delete__(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in set(self, state, dict_, value, initiator, passive, check_old, pop)
#     810                     ))
#     811
# --> 812         value = self.fire_replace_event(state, dict_, value, old, initiator)
#     813         dict_[self.key] = value
#     814
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_replace_event(self, state, dict_, value, previous, initiator)
#     832             value = fn(
#     833                 state, value, previous, initiator or
# --> 834                 self._replace_token or self._init_append_or_replace_token())
#     835
#     836         state._modified_event(dict_, self, previous)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in emit_backref_from_scalar_set_event(state, child, oldchild, initiator)
#    1186                     state.obj(),
#    1187                     initiator,
# -> 1188                     passive=PASSIVE_NO_FETCH)
#    1189         return child
#    1190
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in append(self, state, dict_, value, initiator, passive)
#    1001         collection = self.get_collection(state, dict_, passive=passive)
#    1002         if collection is PASSIVE_NO_RESULT:
# -> 1003             value = self.fire_append_event(state, dict_, value, initiator)
#    1004             assert self.key not in dict_, \
#    1005                 "Collection was loaded during event handling."
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_append_event(self, state, dict_, value, initiator)
#     949             value = fn(
#     950                 state, value,
# --> 951                 initiator or self._append_token or self._init_append_token())
#     952
#     953         state._modified_event(dict_, self, NEVER_SET, True)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/unitofwork.pyc in append(state, item, initiator)
#      45                 (prop.cascade_backrefs or key == initiator.key) and \
#      46                     not sess._contains_state(item_state):
# ---> 47                 sess._save_or_update_state(item_state)
#      48         return item
#      49
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_state(self, state)
#    1694                 state,
#    1695                 halt_on=self._contains_state):
# -> 1696             self._save_or_update_impl(st_)
#    1697
#    1698     def delete(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_impl(self, state)
#    1993             self._save_impl(state)
#    1994         else:
# -> 1995             self._update_impl(state)
#    1996
#    1997     def enable_relationship_loading(self, obj):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _update_impl(self, state, revert_deletion)
#    1976             return
#    1977
# -> 1978         to_attach = self._before_attach(state, obj)
#    1979
#    1980         self._deleted.pop(state, None)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _before_attach(self, state, obj)
#    2060                 "Object '%s' is already attached to session '%s' "
#    2061                 "(this is '%s')" % (state_str(state),
# -> 2062                                     state.session_id, self.hash_key))
#    2063
#    2064         self.dispatch.before_attach(self, obj)
#
# InvalidRequestError: Object '<DamCandidates at 0x15b3b2b90>' is already attached to session '1' (this is '4')
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /Users/bserna/Developer/geodeepdive_template/snorkel/snorkel/viewer.pyc in handle_label_event(self, _, content, buffers)
#     214
#     215                 # Create AnnotatorLabel
# --> 216                 self.annotations[cid] = GoldLabel(key=self.annotator, candidate=candidate, value=value)
#     217                 self.session.add(self.annotations[cid])
#     218
#
# <string> in __init__(self, **kwargs)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     412         except:
#     413             with util.safe_reraise():
# --> 414                 manager.dispatch.init_failure(self, args, kwargs)
#     415
#     416     def get_history(self, key, passive):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/util/langhelpers.pyc in __exit__(self, type_, value, traceback)
#      58             exc_type, exc_value, exc_tb = self._exc_info
#      59             self._exc_info = None   # remove potential circular references
# ---> 60             compat.reraise(exc_type, exc_value, exc_tb)
#      61         else:
#      62             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/state.pyc in _initialize_instance(*mixed, **kwargs)
#     409
#     410         try:
# --> 411             return manager.original_init(*mixed[1:], **kwargs)
#     412         except:
#     413             with util.safe_reraise():
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/ext/declarative/base.pyc in _declarative_constructor(self, **kwargs)
#     648                 "%r is an invalid keyword argument for %s" %
#     649                 (k, cls_.__name__))
# --> 650         setattr(self, k, kwargs[k])
#     651 _declarative_constructor.__name__ = '__init__'
#     652
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in __set__(self, instance, value)
#     222     def __set__(self, instance, value):
#     223         self.impl.set(instance_state(instance),
# --> 224                       instance_dict(instance), value, None)
#     225
#     226     def __delete__(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in set(self, state, dict_, value, initiator, passive, check_old, pop)
#     810                     ))
#     811
# --> 812         value = self.fire_replace_event(state, dict_, value, old, initiator)
#     813         dict_[self.key] = value
#     814
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_replace_event(self, state, dict_, value, previous, initiator)
#     832             value = fn(
#     833                 state, value, previous, initiator or
# --> 834                 self._replace_token or self._init_append_or_replace_token())
#     835
#     836         state._modified_event(dict_, self, previous)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in emit_backref_from_scalar_set_event(state, child, oldchild, initiator)
#    1186                     state.obj(),
#    1187                     initiator,
# -> 1188                     passive=PASSIVE_NO_FETCH)
#    1189         return child
#    1190
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in append(self, state, dict_, value, initiator, passive)
#    1001         collection = self.get_collection(state, dict_, passive=passive)
#    1002         if collection is PASSIVE_NO_RESULT:
# -> 1003             value = self.fire_append_event(state, dict_, value, initiator)
#    1004             assert self.key not in dict_, \
#    1005                 "Collection was loaded during event handling."
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/attributes.pyc in fire_append_event(self, state, dict_, value, initiator)
#     949             value = fn(
#     950                 state, value,
# --> 951                 initiator or self._append_token or self._init_append_token())
#     952
#     953         state._modified_event(dict_, self, NEVER_SET, True)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/unitofwork.pyc in append(state, item, initiator)
#      45                 (prop.cascade_backrefs or key == initiator.key) and \
#      46                     not sess._contains_state(item_state):
# ---> 47                 sess._save_or_update_state(item_state)
#      48         return item
#      49
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_state(self, state)
#    1694                 state,
#    1695                 halt_on=self._contains_state):
# -> 1696             self._save_or_update_impl(st_)
#    1697
#    1698     def delete(self, instance):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _save_or_update_impl(self, state)
#    1993             self._save_impl(state)
#    1994         else:
# -> 1995             self._update_impl(state)
#    1996
#    1997     def enable_relationship_loading(self, obj):
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _update_impl(self, state, revert_deletion)
#    1976             return
#    1977
# -> 1978         to_attach = self._before_attach(state, obj)
#    1979
#    1980         self._deleted.pop(state, None)
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in _before_attach(self, state, obj)
#    2060                 "Object '%s' is already attached to session '%s' "
#    2061                 "(this is '%s')" % (state_str(state),
# -> 2062                                     state.session_id, self.hash_key))
#    2063
#    2064         self.dispatch.before_attach(self, obj)
#
# InvalidRequestError: Object '<DamCandidates at 0x15b3b2290>' is already attached to session '1' (this is '4')

# %%
sv.get_selected()
# Out:
# DamCandidates(Span("breaching", sentence=51322, chars=[41,49], words=[6,6]), Span("Mill Dam", sentence=51322, chars=[61,68], words=[9,10]))

# %%
if 'CI' not in os.environ:
    print(unicode(sv.get_selected()))

# %% [markdown]
# ## Session commit
# note: figure out another method to save/commit changes

# %%
session.add(test_sents)
session.add(train_sents)
session.add(dev_sents)
session.commit()
# Out:
# ---------------------------------------------------------------------------
# UnmappedInstanceError                     Traceback (most recent call last)
# <ipython-input-30-e0745888aa5f> in <module>()
# ----> 1 session.add(test_sents)
#       2 session.add(train_sents)
#       3 session.add(dev_sents)
#       4 session.commit()
#
# /Users/bserna/anaconda/envs/snorkle/lib/python2.7/site-packages/sqlalchemy/orm/session.pyc in add(self, instance, _warn)
#    1673             state = attributes.instance_state(instance)
#    1674         except exc.NO_STATE:
# -> 1675             raise exc.UnmappedInstanceError(instance)
#    1676
#    1677         self._save_or_update_state(state)
#
# UnmappedInstanceError: Class '__builtin__.set' is not mapped

# %% [markdown]
# ## Traversing context hierarchy
# Candidates are tuples of Context-type objects, most cases Spans

# %%
c = train_cands[0]
c.get_contexts()

# %%
span = c.get_contexts()[0]
print(span)
print(span.get_parent())
print(span.get_parent().get_parent())

# %%
print(span.get_span())
print(span.get_attrib_tokens())
print(span.get_attrib_tokens('pos_tags'))

# %%
'''
repeating for dev and test data
'''
# %time
for i, sents in enumerate([dev_sents, test_sents]):
    dam_extractor.apply(sents, split = i+1)
    print('Number of candidates: ', session.query(Dam).filter(Dam.split == i+1).count())
